# %%
library("readr")
library("dplyr")

# %% [markdown]
# Te dwa fragmenty kodu pobiorą informacje bezpośrednio ze środowiska Github:

# %%
ratings <- read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-01-25/ratings.csv')
details <- read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-01-25/details.csv')

# %% [markdown]
#  # Zadanie 1:
# Ramka *ratings* zawiera informacje o ocenach roznych gier. Zmienna *average* zawiera informacje o sredniej ocenie kazdej z gier.
#
# 1. Zrob histogram zmiennej "average".

# %% [markdown]
# 2. Wyznacz srednia, odchylenie standardowe i wszystkie tercyle tej zmiennej.

# %% [markdown]
#    3. Stworz zmienna *rating_cat* zawierajaca porzadkowa informacje o tym,
#       czy dana gra jest oceniana nisko, przecietnie czy wysoko.
#       Samodzielnie okresl, gdzie powinny znajdowac sie
#       punkty odciecia dla tych kategorii.

# %% [markdown]
# #Zadane 2:
#
# Zmienna *year* w ramce danych *ratings* przyjmuje wartosc *0*, ktora jest brakiem danych
#
# Zamien wartosc "0" dla tej zmiennej na brak danych (NA). Wykorzystaj informacje z [linku](https://cran.r-project.org/web/packages/naniar/vignettes/replace-with-na.html):

# %% [markdown]
# Stworz nowa ramke danych *wybrane* zawierajaca wylacznie informacje o grach ktore powstaly po roku 2017 i wylacznie zmienne *id*, *average* oraz *bayes_average*

# %% [markdown]
# Uzyskana w poprzednim poleceniu ramke przeksztalc do postaci dlugiej ze zmienna *measure* zawierajaca nazwe obliczanej sredniej i zmienna *value* zawierajaca wartosc danej sredniej dla danej gry.

# %% [markdown]
# # Zadanie 3:
# Ramka "details" zawiera szczegolowe informacje o charakterystykach  poszczegolnych gier.
#
# Wykorzystaj zmienna *minplayers* oznaczajaca minimalna liczbe graczy. Stworz nowa ramke danych *grydo4* zawierajaca wylacznie informacje o grach, ktore nie wymagaja wiecej niz czterech graczy.

# %% [markdown]
# Dla nowo utworzonej ramki danych, oblicz srednia i odchylenie standardowe czasu rozgrywki (zmienna *playingtime*) dla gier o roznej liczbie graczy.

# %% [markdown]
# Narysuj wyznaczone srednie na wykresie slupkowym. Dodaj slupki bledow odpowiadajace obliczonym odchyleniom standardowym. Slupki bledow wygladaja tak jak w [linku](https://r-graph-gallery.com/4-barplot-with-error-bar.html)
